# %%
import sys
sys.path.append('../src')
from preprocessing import preprocess_image
from segmentation import segment_image
from features import extract_all_features

img_path = '../data/BCCD/train/img/BloodImage_00001.jpeg'
processed = preprocess_image(img_path)
contours, _, _, _ = segment_image(processed)

features = extract_all_features(contours[0], processed)
print(f"Feature vector length: {len(features)}")
print(f"Features: {[round(f,3) for f in features]}")
# Out:
# Feature vector length: 21
# Features: [335.5, 97.497, 0.444, np.float64(0.884), 0.799, np.float64(0.412), 1.807, np.float64(90.913), np.float64(81.457), np.float64(31.024), np.float64(11.368), np.float64(153.025), np.float64(29.163), np.float64(0.064), np.float64(29.742), np.float64(0.307), np.float64(8.774), 65, 266, 204, 94]

# %%
import sys
sys.path.append('../src')
from preprocessing import preprocess_image
from segmentation import segment_image
from features import extract_all_features

img_path = '../data/BCCD/train/img/BloodImage_00001.jpeg'
processed = preprocess_image(img_path)
contours, _, _ = segment_image(processed)

features = extract_all_features(contours[0], processed)
print(f"Feature vector length: {len(features)}")
print(f"Features: {[round(f,3) for f in features]}")
# Out:
# Feature vector length: 21
# Features: [116.0, 54.284, 0.495, np.float64(0.95), 0.903, np.float64(0.79), 1.557, np.float64(83.141), np.float64(83.339), np.float64(19.504), np.float64(6.489), np.float64(169.301), np.float64(21.402), np.float64(0.094), np.float64(22.932), np.float64(0.329), np.float64(7.5), 31, 108, 94, 43]
