# %%
import os
os.chdir(r'F:\Acdemics\Sem 8\Computer_Vision\Image_Processing_Project')

from ultralytics import YOLO

model = YOLO(r'runs\detect\runs\stage3_final\weights\best.pt')
metrics = model.val(data='leukemia.yaml', split='test', plots=False)

print("="*40)
print("FINAL EVALUATION RESULTS")
print("="*40)
print(f"mAP@0.5:      {metrics.box.map50:.3f}")
print(f"mAP@0.5:0.95: {metrics.box.map:.3f}")
print(f"Precision:    {metrics.box.mp:.3f}")
print(f"Recall:       {metrics.box.mr:.3f}")
print("="*40)
# Out:
# Ultralytics 8.4.60  Python-3.12.2 torch-2.12.0+cpu CPU (13th Gen Intel Core i5-1335U)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.40.0 ms, read: 1.80.4 MB/s, size: 21.4 KB)
# val: Scanning F:\Acdemics\Sem 8\Computer_Vision\Image_Processing_Project\data\Leukemia_YOLO\test\labels... 489 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 489/489 376.0it/s 1.3s<0.0s
# val: New cache created: F:\Acdemics\Sem 8\Computer_Vision\Image_Processing_Project\data\Leukemia_YOLO\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 31/31 1.7s/it 52.0s1.6ss
#                    all        489        489      0.996      0.999      0.995      0.995
#                 Normal         67         67      0.992          1      0.995      0.995
#                  Blast        422        422          1      0.998      0.995      0.995
# ...

# %%
import os
os.chdir(r'F:\Acdemics\Sem 8\Computer_Vision\Image_Processing_Project')

from ultralytics import YOLO

model = YOLO(r'runs\detect\runs\stage3_final\weights\best.pt')
metrics = model.val(data='leukemia.yaml', split='test', plots=True)

print("="*40)
print("FINAL EVALUATION RESULTS")
print("="*40)
print(f"mAP@0.5:      {metrics.box.map50:.3f}")
print(f"mAP@0.5:0.95: {metrics.box.map:.3f}")
print(f"Precision:    {metrics.box.mp:.3f}")
print(f"Recall:       {metrics.box.mr:.3f}")
print("="*40)
# Out:
# Ultralytics 8.4.60  Python-3.12.2 torch-2.12.0+cpu CPU (13th Gen Intel Core i5-1335U)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 141.629.1 MB/s, size: 22.8 KB)
# val: Scanning F:\Acdemics\Sem 8\Computer_Vision\Image_Processing_Project\data\Leukemia_YOLO\test\labels.cache... 489 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 489/489  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 31/31 2.6s/it 1:223.3sss
#                    all        489        489      0.996      0.999      0.995      0.995
#                 Normal         67         67      0.992          1      0.995      0.995
#                  Blast        422        422          1      0.998      0.995      0.995
# Speed: 1.6ms preprocess, 156.5ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to C:\Users\Chathumi\runs\detect\val-6
# ...
